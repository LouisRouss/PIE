# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.insert(1, '../functions')
import data_utilities as data_u
import dict_utilities as dict_u
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
dict_dir = "../data/data_dict.pkl"
data_folder = "../data/"
dict_u.reset_dict(dict_dir)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
news_to_read = 'Reuters'
format_cols = ['Text', 'Date', 'Author']

search_words=['google']

data_u.add_news_to_dict(search_words, data_folder, news_to_read, dict_dir, format_cols)

codes_dir = "../data/twitter_codes.txt"
codes = data_u.get_codes(codes_dir)
search_words=['amazon']
data_u.add_tweets_to_dict(search_words, "2020-11-13", 50, "en", codes, format_cols, dict_dir, retweet=False)
# Out:
# Authentification ok

# %%
search_id = 'Google'
codes_dir = "../data/twitter_codes.txt"
codes = data_u.get_codes(codes_dir)
format_cols = ['Text', 'Date', 'Author']
data_u.search_author(search_id,  "2020-11-13", 50, "en", codes, format_cols, retweet=False)
# Out:
# Authentification ok
#                                                  Text                Date  \
# 0   @kwesi_wallace @googledevs Hi, Kwesi. Thanks f... 2020-11-22 01:26:20
# 1   Black-owned businesses have closed at 2x the r... 2020-11-20 21:11:27
# 2   When it comes to self-doubt, your brain 🧠 can ... 2020-11-20 20:09:57
# 3   @mohamedmazoir2 Hmm. Just to confirm, are you ... 2020-11-20 17:52:05
# 4   Your video calls are about to get a glow up. 💄... 2020-11-20 17:35:43
# 5   @McNamaraGreg Hi Greg. We suggest contacting t... 2020-11-20 17:35:12
# 6   @AndreaJeanine18 Hmm. Let's see what we can do... 2020-11-20 17:31:40
# 7   @AnujYad76016128 Hi Anuj. Let's see what we ca... 2020-11-20 15:55:58
# 8   @abdurrehman_net Hmm. Let's see what we can do... 2020-11-20 13:29:18
# 9   @chhotikhs Hi Prabhakar. Let's see what we can... 2020-11-20 13:28:04
# 10  @NikeshDhimal16 Hmm. Just to confirm, have you... 2020-11-20 13:27:19
# 11  @KomodorDragon Hi there. Just to confirm, are ... 2020-11-20 13:24:05
# 12  @Noname61526672 Hi there. Let's see what we ca... 2020-11-20 12:40:00
# 13  @jkhk62 Hi there. Are you getting a specific e... 2020-11-20 11:56:52
# 14  @MichaelCCash2 Hi Michael. Just to confirm, ha... 2020-11-20 11:56:14
# 15  @inTirNaNog Hi Lottie. Are you getting a speci... 2020-11-20 11:55:34
# 16  @ImWatchingToo Hi there. Are you getting a spe... 2020-11-20 11:53:03
# 17  @AyoubTo91328435 Hi Ayoub. We'd like to move t... 2020-11-20 11:44:03
# 18  @dianisiamusic Mind if we jump in, Diana? With... 2020-11-20 11:43:33
# 19  @645kst Hi there. Just to confirm, have you al... 2020-11-20 11:42:52
# 20  @yutecentral Hi there. Are you getting a speci... 2020-11-20 11:41:58
# 21  @KuldeepLakra15 Hi Kuldeep. Let's see what we ... 2020-11-20 11:40:20
# 22  @Tubsiwub Hi Tristan. Let's see what we can do... 2020-11-20 11:35:05
# 23  @sodamnfab_ Hmm. We'd like to move this conver... 2020-11-20 11:33:00
# 24  @DarkShadowWolfi Hmm. Let's see what we can do... 2020-11-20 11:31:34
# 25  @monsterdrift You're welcome. Feel free to rea... 2020-11-20 11:29:49
# 26  @AxtheticlyHD Hmm. We suggest adding extra lay... 2020-11-20 11:28:36
# 27  @ShwetaKatoch1 Let's see what we can do to hel... 2020-11-20 11:28:11
# 28  @WoodpeckerGFB Hi Mehmet. Just to confirm, hav... 2020-11-20 11:19:05
# 29  @noobgamers1989 Hmm. We'd like to move this co... 2020-11-20 11:18:20
# 30  @renopangpang Hi Reno. If she sends us a tweet... 2020-11-20 10:55:58
# 31  @karmalffy Hmm. Let's see what we can do to he... 2020-11-20 10:55:43
# 32  @natasakorfiotou Hmm. Let's see what we can do... 2020-11-20 10:55:11
# 33  @gaurav_tekkie Hi Gaurav. Let's see what we ca... 2020-11-20 10:44:10
# 34  @BannersVoid Hi there. Just to confirm, are yo... 2020-11-20 10:37:59
# 35  @Ash_Fox01 Hi there. Just to confirm, have you... 2020-11-20 10:37:13
# 36  @Happy_Omelette You're welcome. We'd suggest a... 2020-11-20 10:16:35
# 37  @Ankushjha1505 We do want to help. Please foll... 2020-11-20 10:15:04
# 38  @thelysian_ Hmm. Could you give us the exact w... 2020-11-20 10:14:01
# 39  @dhuma1981 Glad you're happy with the experien... 2020-11-20 10:06:15
# 40  @S3C_MM You're welcome! Feel free to reach out... 2020-11-20 10:04:43
# 41  @harsh010494 Mind if we jump in, Harsh? Thanks... 2020-11-20 10:03:08
# 42  @6653ja Hi again. Let's see what we can do to ... 2020-11-20 09:45:15
# 43  @RodmillLopez We'd like to help. Have you alre... 2020-11-20 09:21:15
# 44  @rsrsrahul9797 Hi Rahul. We'd like to move thi... 2020-11-20 09:19:39
# 45  @JOaihimire Hi there. Are you getting a specif... 2020-11-20 09:18:11
# 46  @_permanentwaves You're welcome. Feel free to ... 2020-11-20 08:34:16
# 47  @r4cingstrip3s Hi Jaeden. Just to confirm, hav... 2020-11-20 08:33:19
# 48  @Jony_Sarao Hi Jony. Just to confirm, did you ... 2020-11-20 08:32:27
# 49  @KNRVLG518533 Hi there. Just to confirm, did y... 2020-11-20 08:31:51
#
#     Author
# 0   Google
# 1   Google
# 2   Google
# 3   Google
# 4   Google
# 5   Google
# 6   Google
# 7   Google
# 8   Google
# 9   Google
# 10  Google
# 11  Google
# 12  Google
# 13  Google
# 14  Google
# 15  Google
# 16  Google
# 17  Google
# 18  Google
# 19  Google
# 20  Google
# 21  Google
# 22  Google
# 23  Google
# 24  Google
# 25  Google
# 26  Google
# 27  Google
# 28  Google
# 29  Google
# 30  Google
# 31  Google
# 32  Google
# 33  Google
# 34  Google
# 35  Google
# 36  Google
# 37  Google
# 38  Google
# 39  Google
# 40  Google
# 41  Google
# 42  Google
# 43  Google
# 44  Google
# 45  Google
# 46  Google
# 47  Google
# 48  Google
# 49  Google
